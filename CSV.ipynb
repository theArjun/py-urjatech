# %% [markdown]
# ![Header Banner](https://i.ibb.co/n7vXffB/Screenshot-from-2020-11-01-08-30-40.png)

# %% [markdown]
# # CSV Files

# %%
import csv

# %%
my_csv_file = open('csv_demo.csv','r')
reading = csv.reader(my_csv_file)

# %%
for row in reading:
    print(row)
# Out:
# ['name', 'roll', 'percentage', 'division', 'grade']
# ['arjun adhikari', '5', '90', 'first', '10']
# ['ashutosh sunar', '2', '95', 'distinction', '10']

# %% [markdown]
# ### Task

# %%
my_mock_data_file = open('MOCK_DATA.csv', 'r')

# %%
my_csv = csv.reader(my_mock_data_file)

# %%
my_csv_data = []
for row in my_csv:
    my_csv_data.append(row)

# %%
heading = my_csv_data[0]

# %%
heading
# Out:
# ['first_name', 'last_name', 'email', 'gender', 'city']

# %%
data = my_csv_data[1:]

# %%
data
# Out:
# [['Flynn', 'Pygott', 'fpygott0@google.com.au', 'Male', 'Opechenskiy Posad'],
#  ['Elias', 'Saxon', 'esaxon1@economist.com', 'Male', 'Shahrak'],
#  ['Ruthanne', 'Vella', 'rvella2@mtv.com', 'Female', 'Banjar Kawan'],
#  ['Bourke', 'Bratten', 'bbratten3@unicef.org', 'Male', 'Al Qiţena'],
#  ['Hyatt', 'Luty', 'hluty4@umn.edu', 'Male', 'Glagahdowo'],
#  ['Maximilian', 'Singers', 'msingers5@4shared.com', 'Male', 'Concepción'],
#  ['Leola', 'Mathers', 'lmathers6@csmonitor.com', 'Female', 'Zandak'],
#  ['Everett',
#   'Websdale',
#   'ewebsdale7@miibeian.gov.cn',
#   'Male',
#   'Governor’s Harbour'],
#  ['Lucian', 'Raffeorty', 'lraffeorty8@google.es', 'Male', 'Ñuñoa'],
#  ['Leslie', 'Gatus', 'lgatus9@feedburner.com', 'Male', 'Ikang'],
#  ['Emili', 'Gibbard', 'egibbarda@timesonline.co.uk', 'Female', 'Lizhai'],
#  ['Ansell', 'Connerly', 'aconnerlyb@amazon.co.uk', 'Male', 'Mandōl'],
#  ['Brand', 'Tynemouth', 'btynemouthc@quantcast.com', 'Male', 'Kanzaki'],
# ...

# %%
user_row = int(input('Enter a row : '))
user_field = input('enter a field name : ')
# Out:
# Enter a row : 4
# enter a field name : city

# %%
user_index = heading.index(user_field)

# %%
user_record = data[user_row]

# %%
user_record
# Out:
# ['Hyatt', 'Luty', 'hluty4@umn.edu', 'Male', 'Glagahdowo']

# %%
user_record[user_index]
# Out:
# 'Glagahdowo'
